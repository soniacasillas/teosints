# %% [markdown]
# # Pràctica prèvia: Familiarització amb Jupyter Notebook (Binder)
#
# Aquest notebook és només una pràctica prèvia per tal que us familiaritzeu amb l'entorn abans de la prova pràctica oficial.

# %% [markdown]
# <div style="color:#1f77b4; background-color:#f2f6fb; padding:12px; border-radius:6px; margin:12px 0;">
# <strong>Instruccions</strong><br>
# - Els blocs de text contenen explicacions i preguntes.<br>
# - Els blocs de codi tenen fons gris i s'han d'executar.<br>
# - Per executar un bloc de codi: fes clic dins del bloc i prem ▶.<br>
# - Pots executar un bloc tantes vegades com vulguis.
# </div>

# %% [markdown]
# ## Exemple de bloc de text
#
# Pots escriure text en **negreta**, *cursiva* o crear llistes:
# - Element 1
# - Element 2

# %% [markdown]
# <div style="background-color:#fff4cc; padding:12px 14px; border-radius:6px; margin:12px 0;">
# <strong>Pregunta 1.</strong><br>
# Què passa quan executes el bloc de codi següent?
# <ol style="list-style-type: upper-alpha;">
# <li>Es mostra un missatge per pantalla.</li>
# <li>S'esborra el contingut del notebook.</li>
# <li>No passa res.</li>
# </ol>
# </div>

# %%
print('Hola! Aquest és un bloc de codi en Jupyter Notebook.')

# %%
# Prova a modificar el número i tornar a executar el codi
x = 5
print('El valor de x és:', x)
